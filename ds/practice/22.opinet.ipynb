# %%
from bs4 import BeautifulSoup as bs
import requests
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome(service= Service('D:/source/web_scrap/driver/chromedriver.exe'))
driver.get('https://www.opinet.co.kr/searRgSelect.do')

# %%
xpath = """//*[@id="SIGUNGU_NM0"]"""
gu_list_raw = driver.find_element(By.XPATH, xpath) #xpath로 찾아라

# %%
gu_list = gu_list_raw.find_elements(By.TAG_NAME, 'option') #tag_name으로 찾아라

# %%
gu_names = [option.get_attribute('value') for option in gu_list]

# %%
print(gu_names)
# Out:
# ['', '강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구', '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']

# %%
gu_names = gu_names[1:]

# %%
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
gu_list_raw.send_keys(gu_names[0])

# %%
#xpath = """//*[@id="glopopd_excel"]/span"""
#driver.find_element(By.XPATH, xpath).click()

# %%
import time
from tqdm.notebook import tqdm

# %%
for gu in tqdm(gu_names):
    xpath = """//*[@id="SIGUNGU_NM0"]""" #span은 ui 기능 없음
    element = driver.find_element(By.XPATH, xpath)
    element.send_keys(gu)
    time.sleep(3)
    xpath = """//*[@id="glopopd_excel"]"""
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(1)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
print(len(gu_names))
# Out:
# 25

# %%
driver.close()

# %%
import pandas as pd
from glob import glob

# %%
glob('data/oil/지역_위치별*.xls') # file아래에 *이라는 wild card 줘서 한번에 모두 불러오기 가능
# Out:
# ['data/oil\\지역_위치별(주유소) (1).xls',
#  'data/oil\\지역_위치별(주유소) (10).xls',
#  'data/oil\\지역_위치별(주유소) (11).xls',
#  'data/oil\\지역_위치별(주유소) (12).xls',
#  'data/oil\\지역_위치별(주유소) (13).xls',
#  'data/oil\\지역_위치별(주유소) (14).xls',
#  'data/oil\\지역_위치별(주유소) (15).xls',
#  'data/oil\\지역_위치별(주유소) (16).xls',
#  'data/oil\\지역_위치별(주유소) (17).xls',
#  'data/oil\\지역_위치별(주유소) (18).xls',
#  'data/oil\\지역_위치별(주유소) (19).xls',
#  'data/oil\\지역_위치별(주유소) (2).xls',
#  'data/oil\\지역_위치별(주유소) (20).xls',
#  'data/oil\\지역_위치별(주유소) (21).xls',
#  'data/oil\\지역_위치별(주유소) (22).xls',
#  'data/oil\\지역_위치별(주유소) (23).xls',
#  'data/oil\\지역_위치별(주유소) (24).xls',
#  'data/oil\\지역_위치별(주유소) (3).xls',
#  'data/oil\\지역_위치별(주유소) (4).xls',
#  'data/oil\\지역_위치별(주유소) (5).xls',
#  'data/oil\\지역_위치별(주유소) (6).xls',
#  'data/oil\\지역_위치별(주유소) (7).xls',
#  'data/oil\\지역_위치별(주유소) (8).xls',
#  'data/oil\\지역_위치별(주유소) (9).xls',
#  'data/oil\\지역_위치별(주유소).xls']

# %%
station_files = glob('data/oil/지역_위치별*.xls')
station_files
# Out:
# ['data/oil\\지역_위치별(주유소) (1).xls',
#  'data/oil\\지역_위치별(주유소) (10).xls',
#  'data/oil\\지역_위치별(주유소) (11).xls',
#  'data/oil\\지역_위치별(주유소) (12).xls',
#  'data/oil\\지역_위치별(주유소) (13).xls',
#  'data/oil\\지역_위치별(주유소) (14).xls',
#  'data/oil\\지역_위치별(주유소) (15).xls',
#  'data/oil\\지역_위치별(주유소) (16).xls',
#  'data/oil\\지역_위치별(주유소) (17).xls',
#  'data/oil\\지역_위치별(주유소) (18).xls',
#  'data/oil\\지역_위치별(주유소) (19).xls',
#  'data/oil\\지역_위치별(주유소) (2).xls',
#  'data/oil\\지역_위치별(주유소) (20).xls',
#  'data/oil\\지역_위치별(주유소) (21).xls',
#  'data/oil\\지역_위치별(주유소) (22).xls',
#  'data/oil\\지역_위치별(주유소) (23).xls',
#  'data/oil\\지역_위치별(주유소) (24).xls',
#  'data/oil\\지역_위치별(주유소) (3).xls',
#  'data/oil\\지역_위치별(주유소) (4).xls',
#  'data/oil\\지역_위치별(주유소) (5).xls',
#  'data/oil\\지역_위치별(주유소) (6).xls',
#  'data/oil\\지역_위치별(주유소) (7).xls',
#  'data/oil\\지역_위치별(주유소) (8).xls',
#  'data/oil\\지역_위치별(주유소) (9).xls',
#  'data/oil\\지역_위치별(주유소).xls']

# %%
#conda install xlrd
tmp_raw = []
for file_name in station_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)

# %%
print(len(tmp_raw))
# Out:
# 25

# %%
station_raw = pd.concat(tmp_raw)

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 442 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지역      442 non-null    object
#  1   상호      442 non-null    object
#  2   주소      442 non-null    object
#  3   상표      442 non-null    object
#  4   전화번호    442 non-null    object
#  5   셀프여부    442 non-null    object
#  6   고급휘발유   442 non-null    object
#  7   휘발유     442 non-null    object
#  8   경유      442 non-null    object
#  9   실내등유    442 non-null    object
# dtypes: object(10)
# memory usage: 38.0+ KB

# %%
station_raw.head()
# Out:
#       지역                    상호                            주소      상표  \
# 0  서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  현대오일뱅크
# 1  서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  현대오일뱅크
# 2  서울특별시           (주)소모 신월주유소        서울 강동구 양재대로 1323 (성내동)   GS칼텍스
# 3  서울특별시                 명일주유소          서울 강동구 고덕로 168 (명일동)    자가상표
# 4  서울특별시          대성석유(주)길동주유소              서울 강동구 천호대로 1168   GS칼텍스
#
#            전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0   02-487-2030    Y     -  1569  1439     -
# 1   02-441-0536    N     -  1594  1485     -
# 2  02-6956-6674    Y  1846  1616  1508  1590
# 3  02-3428-1739    Y  1825  1625  1499     -
# 4   02-474-7222    N  1875  1626  1498  1600

# %%
stations = pd.DataFrame(
    {'Oil_store' : station_raw['상호'],
     '주소' : station_raw['주소'],
     '가격' : station_raw['휘발유'],
     '셀프' : station_raw['셀프여부'],
     '상표' : station_raw['상표']}
)

stations.head()
# Out:
#               Oil_store                            주소    가격 셀프      상표
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1569  Y  현대오일뱅크
# 1                구천면주유소         서울 강동구 구천면로 357 (암사동)  1594  N  현대오일뱅크
# 2           (주)소모 신월주유소        서울 강동구 양재대로 1323 (성내동)  1616  Y   GS칼텍스
# 3                 명일주유소          서울 강동구 고덕로 168 (명일동)  1625  Y    자가상표
# 4          대성석유(주)길동주유소              서울 강동구 천호대로 1168  1626  N   GS칼텍스

# %%
stations['구'] = [address.split()[1] for address in stations['주소']]
stations.head()
# Out:
#               Oil_store                            주소    가격 셀프      상표    구
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1569  Y  현대오일뱅크  강동구
# 1                구천면주유소         서울 강동구 구천면로 357 (암사동)  1594  N  현대오일뱅크  강동구
# 2           (주)소모 신월주유소        서울 강동구 양재대로 1323 (성내동)  1616  Y   GS칼텍스  강동구
# 3                 명일주유소          서울 강동구 고덕로 168 (명일동)  1625  Y    자가상표  강동구
# 4          대성석유(주)길동주유소              서울 강동구 천호대로 1168  1626  N   GS칼텍스  강동구

# %%
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '강남구'], dtype=object)

# %%
stations[stations['가격'] == '-']
# Out:
#    Oil_store               주소 가격 셀프     상표     구
# 17  (주)파랑에너지  서울 동대문구 망우로 126  -  Y  GS칼텍스  동대문구

# %%
stations = stations[stations['가격'] != '-']
stations.head()
# Out:
#               Oil_store                            주소    가격 셀프      상표    구
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1569  Y  현대오일뱅크  강동구
# 1                구천면주유소         서울 강동구 구천면로 357 (암사동)  1594  N  현대오일뱅크  강동구
# 2           (주)소모 신월주유소        서울 강동구 양재대로 1323 (성내동)  1616  Y   GS칼텍스  강동구
# 3                 명일주유소          서울 강동구 고덕로 168 (명일동)  1625  Y    자가상표  강동구
# 4          대성석유(주)길동주유소              서울 강동구 천호대로 1168  1626  N   GS칼텍스  강동구

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Oil_store  441 non-null    object
#  1   주소         441 non-null    object
#  2   가격         441 non-null    object
#  3   셀프         441 non-null    object
#  4   상표         441 non-null    object
#  5   구          441 non-null    object
# dtypes: object(6)
# memory usage: 24.1+ KB

# %%
stations['가격'] = [float(value) for value in stations['가격']]
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 441 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Oil_store  441 non-null    object
#  1   주소         441 non-null    object
#  2   가격         441 non-null    float64
#  3   셀프         441 non-null    object
#  4   상표         441 non-null    object
#  5   구          441 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 24.1+ KB

# %%
stations.head(20)
# Out:
#                Oil_store                            주소      가격 셀프      상표  \
# 0   재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1569.0  Y  현대오일뱅크
# 1                 구천면주유소         서울 강동구 구천면로 357 (암사동)  1594.0  N  현대오일뱅크
# 2            (주)소모 신월주유소        서울 강동구 양재대로 1323 (성내동)  1616.0  Y   GS칼텍스
# 3                  명일주유소          서울 강동구 고덕로 168 (명일동)  1625.0  Y    자가상표
# 4           대성석유(주)길동주유소              서울 강동구 천호대로 1168  1626.0  N   GS칼텍스
# 5         (주)삼표에너지 고덕주유소           서울 강동구 고덕로 39 (암사동)  1629.0  Y   GS칼텍스
# 6         지에스칼텍스㈜ 동서울주유소        서울 강동구 천호대로 1456 (상일동)  1636.0  Y   GS칼텍스
# 7            (주)소모 성내주유소         서울 강동구 올림픽로 578 (성내동)  1650.0  Y   GS칼텍스
# 8        (주)퍼스트오일 코알라주유소     서울특별시 강동구  올림픽로 556 (성내동)  1650.0  Y   S-OIL
# 9               sk해뜨는주유소         서울 강동구  상일로 132 (강일동)  1655.0  Y   SK에너지
# 10               방아다리주유소          서울 강동구 동남로 811 (명일동)  1685.0  Y   SK에너지
# 11      주)지유에너지직영 오렌지주유소          서울 강동구 성안로 102 (성내동)  1695.0  N   SK에너지
# 12               천호현대주유소           서울 강동구 천중로 67 (천호동)  1799.0  N  현대오일뱅크
# 13                 광성주유소         서울 강동구 올림픽로 673 (천호동)  1948.0  N   S-OIL
# 0         (주)자연에너지 국민주유소       서울 동대문구 답십리로 223 (답십리동)  1519.0  Y  현대오일뱅크
# 1                  풍한주유소               서울 동대문구 안암로 168  1525.0  N   SK에너지
# 2                재정제2주유소         서울 동대문구 사가정로 90 (전농동)  1530.0  Y  현대오일뱅크
# 3                  재정주유소         서울 동대문구 전농로 121 (전농동)  1530.0  Y  현대오일뱅크
# 4                  열린주유소         서울 동대문구 한천로 263 (휘경동)  1537.0  N   S-OIL
# 5               동서울고속주유소               서울 동대문구 한천로 414  1555.0  Y   SK에너지
#
#        구
# 0    강동구
# 1    강동구
# 2    강동구
# 3    강동구
# 4    강동구
# 5    강동구
# 6    강동구
# 7    강동구
# 8    강동구
# 9    강동구
# 10   강동구
# 11   강동구
# 12   강동구
# 13   강동구
# 0   동대문구
# 1   동대문구
# 2   동대문구
# 3   동대문구
# 4   동대문구
# 5   동대문구

# %%
stations.reset_index(inplace=True)

# %%
stations.head(20)
# Out:
#     index             Oil_store                            주소      가격 셀프  \
# 0       0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1569.0  Y
# 1       1                구천면주유소         서울 강동구 구천면로 357 (암사동)  1594.0  N
# 2       2           (주)소모 신월주유소        서울 강동구 양재대로 1323 (성내동)  1616.0  Y
# 3       3                 명일주유소          서울 강동구 고덕로 168 (명일동)  1625.0  Y
# 4       4          대성석유(주)길동주유소              서울 강동구 천호대로 1168  1626.0  N
# 5       5        (주)삼표에너지 고덕주유소           서울 강동구 고덕로 39 (암사동)  1629.0  Y
# 6       6        지에스칼텍스㈜ 동서울주유소        서울 강동구 천호대로 1456 (상일동)  1636.0  Y
# 7       7           (주)소모 성내주유소         서울 강동구 올림픽로 578 (성내동)  1650.0  Y
# 8       8       (주)퍼스트오일 코알라주유소     서울특별시 강동구  올림픽로 556 (성내동)  1650.0  Y
# 9       9              sk해뜨는주유소         서울 강동구  상일로 132 (강일동)  1655.0  Y
# 10     10               방아다리주유소          서울 강동구 동남로 811 (명일동)  1685.0  Y
# 11     11      주)지유에너지직영 오렌지주유소          서울 강동구 성안로 102 (성내동)  1695.0  N
# 12     12               천호현대주유소           서울 강동구 천중로 67 (천호동)  1799.0  N
# 13     13                 광성주유소         서울 강동구 올림픽로 673 (천호동)  1948.0  N
# 14      0        (주)자연에너지 국민주유소       서울 동대문구 답십리로 223 (답십리동)  1519.0  Y
# 15      1                 풍한주유소               서울 동대문구 안암로 168  1525.0  N
# 16      2               재정제2주유소         서울 동대문구 사가정로 90 (전농동)  1530.0  Y
# 17      3                 재정주유소         서울 동대문구 전농로 121 (전농동)  1530.0  Y
# 18      4                 열린주유소         서울 동대문구 한천로 263 (휘경동)  1537.0  N
# 19      5              동서울고속주유소               서울 동대문구 한천로 414  1555.0  Y
#
#         상표     구
# 0   현대오일뱅크   강동구
# 1   현대오일뱅크   강동구
# 2    GS칼텍스   강동구
# 3     자가상표   강동구
# 4    GS칼텍스   강동구
# 5    GS칼텍스   강동구
# 6    GS칼텍스   강동구
# 7    GS칼텍스   강동구
# 8    S-OIL   강동구
# 9    SK에너지   강동구
# 10   SK에너지   강동구
# 11   SK에너지   강동구
# 12  현대오일뱅크   강동구
# 13   S-OIL   강동구
# 14  현대오일뱅크  동대문구
# 15   SK에너지  동대문구
# 16  현대오일뱅크  동대문구
# 17  현대오일뱅크  동대문구
# 18   S-OIL  동대문구
# 19   SK에너지  동대문구

# %%
del stations['index']
stations.head()
# Out:
#               Oil_store                            주소      가격 셀프      상표    구
# 0  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  1569.0  Y  현대오일뱅크  강동구
# 1                구천면주유소         서울 강동구 구천면로 357 (암사동)  1594.0  N  현대오일뱅크  강동구
# 2           (주)소모 신월주유소        서울 강동구 양재대로 1323 (성내동)  1616.0  Y   GS칼텍스  강동구
# 3                 명일주유소          서울 강동구 고덕로 168 (명일동)  1625.0  Y    자가상표  강동구
# 4          대성석유(주)길동주유소              서울 강동구 천호대로 1168  1626.0  N   GS칼텍스  강동구

# %%
#한글 처리 코드
import platform
from matplotlib import font_manager, rc # Runtime Configuration

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin': #macos
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows': #windows os
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
import matplotlib.pyplot as plt
stations.boxplot(column='가격', by = '셀프', figsize= (7,7))
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10,8))
sns.boxplot(x="상표", y="가격", hue="셀프", data=stations, 
            palette="Set3")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="상표", y="가격", hue="셀프", data=stations, 
            palette="Set3")
sns.swarmplot(x="상표", y="가격", data=stations, color=".6")
plt.show()
# Out:
# c:\Users\BIT\AppData\Local\miniconda3\envs\p39-env\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\BIT\AppData\Local\miniconda3\envs\p39-env\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 10.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\BIT\AppData\Local\miniconda3\envs\p39-env\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 18.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\BIT\AppData\Local\miniconda3\envs\p39-env\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import json
import folium
import googlemaps

# %%
stations.sort_values(by = '가격', ascending = False).head(10)
# Out:
#                Oil_store                     주소      가격 셀프      상표    구
# 271                서남주유소           서울 중구 통일로 30  2607.0  N   SK에너지   중구
# 236                서계주유소  서울 용산구  청파로 367 (청파동)  2605.0  N   GS칼텍스  용산구
# 440       (주)만정에너지 삼보주유소  서울 강남구 봉은사로 433 (삼성동)  2578.0  N   GS칼텍스  강남구
# 439  (주)제이제이네트웍스 제이제이주유소         서울 강남구 언주로 716  2398.0  N  현대오일뱅크  강남구
# 270                필동주유소   서울 중구 퇴계로 196 (필동2가)  2369.0  N   GS칼텍스   중구
# 438              SK논현주유소   서울 강남구 논현로 747 (논현동)  2355.0  N   SK에너지  강남구
# 437              갤러리아주유소        서울 강남구 압구정로 426  2275.0  N   SK에너지  강남구
# 261       (주)대양씨앤씨 사직주유소    서울 종로구 사직로 65 (사직동)  2250.0  N   GS칼텍스  종로구
# 269                약수주유소          서울 중구 다산로 173  2246.0  N   GS칼텍스   중구
# 260               경복궁주유소     서울 종로구 율곡로 6 (중학동)  2240.0  N   GS칼텍스  종로구

# %%
stations.sort_values(by = '가격', ascending = True).head(10)
# Out:
#            Oil_store                      주소      가격 셀프      상표    구
# 163          가로공원주유소  서울 양천구 가로공원로 165 (신월동)  1497.0  N   SK에너지  양천구
# 285           화곡역주유소    서울 강서구 강서로 154 (화곡동)  1497.0  Y   알뜰주유소  강서구
# 286           뉴신정주유소   서울 강서구 곰달래로 207 (화곡동)  1497.0  N   알뜰주유소  강서구
# 287  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동)  1497.0  Y  현대오일뱅크  강서구
# 164      플라트(주)서호주유소        서울 양천구 남부순환로 317  1497.0  Y   GS칼텍스  양천구
# 165            현대주유소  서울 양천구 남부순환로 372 (신월동)  1497.0  Y   S-OIL  양천구
# 166   (주)타이거오일 신정주유소    서울 양천구 중앙로 226 (신정동)  1509.0  Y   SK에너지  양천구
# 167           양천구주유소    서울 양천구 국회대로 275 (목동)  1512.0  Y   알뜰주유소  양천구
# 288            목화주유소   서울 강서구 국회대로 251 (화곡동)  1512.0  Y   알뜰주유소  강서구
# 168  지에스이앤알 직영 서울주유소    서울 양천구 신정로 236 (신정동)  1515.0  Y   GS칼텍스  양천구

# %%
import numpy as np
gu_data = pd.pivot_table(stations, index = ['구'], values = ['가격'], aggfunc=np.mean)
gu_data.head()
# Out:
#               가격
# 구
# 강남구  1856.470588
# 강동구  1669.785714
# 강북구  1546.000000
# 강서구  1608.212121
# 관악구  1642.785714

# %%
geo_path = 'data/seoul_geo.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))
map = folium.Map(location=[37.5502, 126.982], 
                 zoom_start=11)
geo_path = 'data/seoul_geo.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))
map = folium.Map(location=[37.5502, 126.982], zoom_start=11)

folium.Choropleth(
    geo_data = geo_str,
    data = gu_data,
    columns = [gu_data.index,'가격'],
    fill_color='PuRd',
    key_on='feature.id'
).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_296a03289abee8856d3e996936f419fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_296a03289abee8856d3e996936f419fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_296a03289abee8856d3e996936f419fd = L.map(
#                 &quot;map_296a03289abee8856d3e996936f419fd&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f784b07aaef97f9abb6545cd765e3643 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_296a03289abee8856d3e996936f419fd);
#
#
#             var choropleth_cde77cebdbebc22b307d494c1849a538 = L.featureGroup(
#                 {}
#             ).addTo(map_296a03289abee8856d3e996936f419fd);
#
#
#         function geo_json_a95e2adc904b752ce95eb54e067d19a6_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d4b9da&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#df65b0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#980043&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc911\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#dd1c77&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f1eef6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_a95e2adc904b752ce95eb54e067d19a6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_a95e2adc904b752ce95eb54e067d19a6 = L.geoJson(null, {
#                 onEachFeature: geo_json_a95e2adc904b752ce95eb54e067d19a6_onEachFeature,
#
#                 style: geo_json_a95e2adc904b752ce95eb54e067d19a6_styler,
#         });
#
#         function geo_json_a95e2adc904b752ce95eb54e067d19a6_add (data) {
#             geo_json_a95e2adc904b752ce95eb54e067d19a6
#                 .addData(data)
#                 .addTo(choropleth_cde77cebdbebc22b307d494c1849a538);
#         }
#             geo_json_a95e2adc904b752ce95eb54e067d19a6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.46240445587048], [127.11117085201238, 37.485708381512445], [127.0719146000724, 37.50224013587669], [127.0690698130372, 37.522279423505026]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11240&quot;, &quot;name&quot;: &quot;\uc1a1\ud30c\uad6c&quot;, &quot;name_eng&quot;: &quot;Songpa-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[

# %%
oil_price_top10 = stations.sort_values(by='가격', 
                                       ascending=False).head(10)
oil_price_top10
# Out:
#                Oil_store                     주소      가격 셀프      상표    구
# 271                서남주유소           서울 중구 통일로 30  2607.0  N   SK에너지   중구
# 236                서계주유소  서울 용산구  청파로 367 (청파동)  2605.0  N   GS칼텍스  용산구
# 440       (주)만정에너지 삼보주유소  서울 강남구 봉은사로 433 (삼성동)  2578.0  N   GS칼텍스  강남구
# 439  (주)제이제이네트웍스 제이제이주유소         서울 강남구 언주로 716  2398.0  N  현대오일뱅크  강남구
# 270                필동주유소   서울 중구 퇴계로 196 (필동2가)  2369.0  N   GS칼텍스   중구
# 438              SK논현주유소   서울 강남구 논현로 747 (논현동)  2355.0  N   SK에너지  강남구
# 437              갤러리아주유소        서울 강남구 압구정로 426  2275.0  N   SK에너지  강남구
# 261       (주)대양씨앤씨 사직주유소    서울 종로구 사직로 65 (사직동)  2250.0  N   GS칼텍스  종로구
# 269                약수주유소          서울 중구 다산로 173  2246.0  N   GS칼텍스   중구
# 260               경복궁주유소     서울 종로구 율곡로 6 (중학동)  2240.0  N   GS칼텍스  종로구

# %%
oil_price_bottom10 = stations.sort_values(by='가격', 
                                          ascending=True).head(10)
oil_price_bottom10
# Out:
#            Oil_store                      주소      가격 셀프      상표    구
# 163          가로공원주유소  서울 양천구 가로공원로 165 (신월동)  1497.0  N   SK에너지  양천구
# 285           화곡역주유소    서울 강서구 강서로 154 (화곡동)  1497.0  Y   알뜰주유소  강서구
# 286           뉴신정주유소   서울 강서구 곰달래로 207 (화곡동)  1497.0  N   알뜰주유소  강서구
# 287  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동)  1497.0  Y  현대오일뱅크  강서구
# 164      플라트(주)서호주유소        서울 양천구 남부순환로 317  1497.0  Y   GS칼텍스  양천구
# 165            현대주유소  서울 양천구 남부순환로 372 (신월동)  1497.0  Y   S-OIL  양천구
# 166   (주)타이거오일 신정주유소    서울 양천구 중앙로 226 (신정동)  1509.0  Y   SK에너지  양천구
# 167           양천구주유소    서울 양천구 국회대로 275 (목동)  1512.0  Y   알뜰주유소  양천구
# 288            목화주유소   서울 강서구 국회대로 251 (화곡동)  1512.0  Y   알뜰주유소  강서구
# 168  지에스이앤알 직영 서울주유소    서울 양천구 신정로 236 (신정동)  1515.0  Y   GS칼텍스  양천구

# %%
gmaps_key = ##
gmaps = googlemaps.Client(key = gmaps_key)

# %%
from tqdm.notebook import tqdm
lat = []
lng = []

for n in tqdm(oil_price_top10.index):
    try:
        tmp_add = oil_price_top10['주소'][n].split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("nan!!")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
#                Oil_store                     주소      가격 셀프      상표    구  \
# 271                서남주유소           서울 중구 통일로 30  2607.0  N   SK에너지   중구
# 236                서계주유소  서울 용산구  청파로 367 (청파동)  2605.0  N   GS칼텍스  용산구
# 440       (주)만정에너지 삼보주유소  서울 강남구 봉은사로 433 (삼성동)  2578.0  N   GS칼텍스  강남구
# 439  (주)제이제이네트웍스 제이제이주유소         서울 강남구 언주로 716  2398.0  N  현대오일뱅크  강남구
# 270                필동주유소   서울 중구 퇴계로 196 (필동2가)  2369.0  N   GS칼텍스   중구
# 438              SK논현주유소   서울 강남구 논현로 747 (논현동)  2355.0  N   SK에너지  강남구
# 437              갤러리아주유소        서울 강남구 압구정로 426  2275.0  N   SK에너지  강남구
# 261       (주)대양씨앤씨 사직주유소    서울 종로구 사직로 65 (사직동)  2250.0  N   GS칼텍스  종로구
# 269                약수주유소          서울 중구 다산로 173  2246.0  N   GS칼텍스   중구
# 260               경복궁주유소     서울 종로구 율곡로 6 (중학동)  2240.0  N   GS칼텍스  종로구
#
#            lat         lng
# 271  37.558375  126.972094
# 236  37.552329  126.968946
# 440  37.511521  127.047172
# 439  37.517647  127.035735
# 270  37.560912  126.993713
# 438  37.518637  127.028238
# 437  37.526784  127.043539
# 261  37.574505  126.966607
# 269  37.559026  127.012661
# 260  37.575463  126.980142

# %%
from tqdm.notebook import tqdm
lat = []
lng = []

for n in tqdm(oil_price_bottom10.index):
    try:
        tmp_add = oil_price_bottom10['주소'][n].split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)
        tmp_loc = tmp_map[0].get('geometry')
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("nan!!")
        
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#            Oil_store                      주소      가격 셀프      상표    구  \
# 163          가로공원주유소  서울 양천구 가로공원로 165 (신월동)  1497.0  N   SK에너지  양천구
# 285           화곡역주유소    서울 강서구 강서로 154 (화곡동)  1497.0  Y   알뜰주유소  강서구
# 286           뉴신정주유소   서울 강서구 곰달래로 207 (화곡동)  1497.0  N   알뜰주유소  강서구
# 287  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동)  1497.0  Y  현대오일뱅크  강서구
# 164      플라트(주)서호주유소        서울 양천구 남부순환로 317  1497.0  Y   GS칼텍스  양천구
# 165            현대주유소  서울 양천구 남부순환로 372 (신월동)  1497.0  Y   S-OIL  양천구
# 166   (주)타이거오일 신정주유소    서울 양천구 중앙로 226 (신정동)  1509.0  Y   SK에너지  양천구
# 167           양천구주유소    서울 양천구 국회대로 275 (목동)  1512.0  Y   알뜰주유소  양천구
# 288            목화주유소   서울 강서구 국회대로 251 (화곡동)  1512.0  Y   알뜰주유소  강서구
# 168  지에스이앤알 직영 서울주유소    서울 양천구 신정로 236 (신정동)  1515.0  Y   GS칼텍스  양천구
#
#            lat         lng
# 163  37.537016  126.834285
# 285  37.540719  126.841530
# 286  37.531580  126.856052
# 287  37.549163  126.846996
# 164  37.538661  126.826837
# 165  37.533873  126.829262
# 166  37.516802  126.854664
# 167  37.530315  126.865517
# 288  37.530040  126.862983
# 168  37.510561  126.847697

# %%
map = folium.Map(location=[37.5502, 126.982], 
                 zoom_start=11)

for n in oil_price_top10.index:
    folium.CircleMarker([oil_price_top10['lat'][n], 
                         oil_price_top10['lng'][n]], 
                         radius=15, color='#CD3181', 
                         fill_color='#CD3181',
                         fill=True).add_to(map)
    
for n in oil_price_bottom10.index:
    folium.CircleMarker([oil_price_bottom10['lat'][n], 
                         oil_price_bottom10['lng'][n]], 
                         radius=15, color='#3186cc', 
                         fill_color='#3186cc',
                         fill=True).add_to(map)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 map = folium.Map(location=[37.5502, 126.982],
#       2                  zoom_start=11)
#       4 for n in oil_price_top10.index:
#       5     folium.CircleMarker([oil_price_top10['lat'][n],
#       6                          oil_price_top10['lng'][n]],
#       7                          radius=15, color='#CD3181',
#       8                          fill_color='#CD3181',
#       9                          fill=True).add_to(map)
#
# NameError: name 'folium' is not defined

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9962c14b8107dd3cadaeb55b85a4059b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9962c14b8107dd3cadaeb55b85a4059b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9962c14b8107dd3cadaeb55b85a4059b = L.map(
#                 &quot;map_9962c14b8107dd3cadaeb55b85a4059b&quot;,
#                 {
#                     center: [37.5502, 126.982],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1fe6c905dae4950349583176561ca899 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9962c14b8107dd3cadaeb55b85a4059b);
#
#
#             var circle_marker_12c6732637eb083dbcf5bfaf700055e4 = L.circleMarker(
#                 [37.5583749, 126.9720939],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#CD3181&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#CD3181&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9962c14b8107dd3cadaeb55b85a4059b);
#
#
#             var circle_marker_f80627ee2aa1be9d82f674a95ba27198 = L.circleMarker(
#                 [37.5523286, 126.9689462],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#CD3181&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#CD3181&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9962c14b8107dd3cadaeb55b85a4059b);
#
#
#             var circle_marker_5d29c522e6af01eb2d37cbe88e11c5c2 = L.circleMarker(
#                 [37.5115207, 127.0471716],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#CD3181&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#CD3181&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9962c14b8107dd3cadaeb55b85a4059b);
#
#
#             var circle_marker_a6ba28520dcbd9508be24db7472137da = L.circleMarker(
#                 [37.5176472, 127.0357349],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#CD3181&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#CD3181&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9962c14b8107dd3cadaeb55b85a4059b);
#
#
#             var circle_marker_d6fe3a21c93530dbc46ae1489f190085 = L.circleMarker(
#                 [37.56091199999999, 126.9937135],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#CD3181&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#CD3181&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9962c14b8107dd3cadaeb55b85a4059b);
#
#
#             var circle_marker_7d220e3c2e1a1261c73ef339f693ab4a = L.circleMarker(
#                 [37.5186368, 127.028238],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#CD3181&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#CD3181&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9962c14b8107dd3cadaeb55b85a4059b);
#
#
#             var circle_marker_a1e85601f77d94
